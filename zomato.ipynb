# %% [markdown]
# # Name: Priti Chauhan
# Batch: 1845

# %% [raw]
# Problem statement : In this dataset predict 2 things –
# 1) Average Cost for two
#
# 2) Price range
#
#
# Columns description:
# Restaurant Id: Unique id of every restaurant across various cities of the world
# Restaurant Name: Name of the restaurant
# Country Code: Country in which restaurant is located
# City: City in which restaurant is located
# Address: Address of the restaurant
# Locality: Location in the city
# Locality Verbose: Detailed description of the locality
# Longitude: Longitude coordinate of the restaurant’s location
# Latitude: Latitude coordinate of the restaurant’s location
# Cuisines: Cuisines offered by the restaurant
# Average Cost for two: Cost for two people in different currencies (local currency)
# Currency: Currency of the country
# Has Table booking: yes/no
# Has Online delivery: yes/ no
# Is delivering: yes/ no
# Switch to order menu: yes/no
# Price range: range of price of food
# Aggregate Rating: Average rating out of 5
# Rating color: depending upon the average rating color
# Rating text: text on the basis of rating of rating
# Votes: Number of ratings given
# Switch to order menu is NO for all observations, hence it’s of no value.

# %%
import pandas as pd 
import numpy as np 

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings 
warnings.filterwarnings('ignore')

# %%
df1= pd.read_csv('zomato.csv')

# %%
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df2= pd.read_csv('country_code.csv')

# %%
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df1.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Country Code', 'Country'], dtype='object')

# %%
df = pd.merge (df1,df2)

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# # Exploration

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730               Naml۱ Gurme           208  ��stanbul
# 9547        5908749              Ceviz A��ac۱           208  ��stanbul
# 9548        5915807                     Huqqa           208  ��stanbul
# 9549        5916112               A���k Kahve           208  ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address     Locality  \
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...     Karak�_y
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...    Ko��uyolu
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karak�_y, ��stanbul  28.977392  41.022793
# ...

# %%
df.sample(5)
# Out:
#       Restaurant ID       Restaurant Name  Country Code       City  \
# 5358           6226  Sonu Sudh Bhojnalaya             1  New Delhi
# 9422        6200110              Aalishan           166       Doha
# 9217        3200440         Kabir Kitchen             1   Vadodara
# 1578            338                  Sage             1    Gurgaon
# 9292       18409146           Fish Streat            94    Jakarta
#
#                                                 Address  \
# 5358  B 1/1 B, Janta Flat, Mayur Vihar Phase 3, New ...
# 9422  Opposite Universal Cooling System, Ibn Seena S...
# 9217  R.C. Dutt Road,Opposite Concord Building, Alka...
# 1578  Food Court, MGF Metropolitan Mall, MG Road, Gu...
# 9292  Jl. Tanjung Duren Utara III, Blok M Kav. 32, T...
#
#                             Locality                         Locality Verbose  \
# 5358             Mayur Vihar Phase 3           Mayur Vihar Phase 3, New Delhi
# ...

# %%
df.shape
# Out:
# (9551, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# Data Description:
# Data is having 9551 entries, 0 to 9550
# Data having 22 columns and 9551 Rows
# All the columns are having 9551 Non-Null value, means data is not having any null values.
# Out of 21 columns we have 3 float, 5 int64 and 14 Object type values.
# Here we can see Average cost for two & price range are in int64 type.

# %% [markdown]
# Checking null values

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# As we can see that only Cuisines has 9 NaN values, rest of the dataset is clean.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isin([" "]).sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
#Checkign any '? ' values present in the columns 
df.isin(["?"]).sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
missing = pd.DataFrame((df.isnull().sum())*100/df.shape[0]).reset_index()
plt.figure(figsize=(16,5))
ax = sns.pointplot('index',0,data=missing)
plt.xticks(rotation =90,fontsize =11)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %% [markdown]
# We can clearly see missing values present in the dataset and it is in Cuisines Columns only

# %%
nan_values = df.isna()
nan_columns = nan_values.any()

columns_with_nan = df.columns[nan_columns].tolist()
print(columns_with_nan)
# Out:
# ['Cuisines']

# %%
print(df['Cuisines'].unique())
# Out:
# ['French, Japanese, Desserts' 'Japanese'
#  'Seafood, Asian, Filipino, Indian' ... 'Burger, Izgara'
#  'World Cuisine, Patisserie, Cafe' 'Italian, World Cuisine']

# %%
# to fill nan values with no dishes
df['Cuisines']=df['Cuisines'].fillna("No Cuisines")

# %%
len(df[df['Cuisines']=='No Cuisines'])
# Out:
# 9

# %% [markdown]
# Now there is no nan values in dataset

# %%
# Value counts of each columns
for i in df.columns:
        print(df[i].value_counts())
        print('\n\n')
        print ('*'*100)
# Out:
# 6317637     1
# 18254520    1
# 18462589    1
# 18336474    1
# 18336477    1
#            ..
# 313059      1
# 763         1
# 7557        1
# 525         1
# 5927402     1
# Name: Restaurant ID, Length: 9551, dtype: int64
#
#
#
# ****************************************************************************************************
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7446, dtype: int64
#
#
#
# ****************************************************************************************************
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# ...

# %%
# Dropping Address coloum from the dataset bcz it is not making any sense to know the exact address
df.drop("Address",axis=1,inplace=True)

# %%
# Checking number of unique values in each column
df.nunique().to_frame("No of Unique Values")
# Out:
#                       No of Unique Values
# Restaurant ID                        9551
# Restaurant Name                      7446
# Country Code                           15
# City                                  141
# Locality                             1208
# Locality Verbose                     1265
# Longitude                            8120
# Latitude                             8677
# Cuisines                             1826
# Average Cost for two                  140
# Currency                               12
# Has Table booking                       2
# Has Online delivery                     2
# Is delivering now                       2
# Switch to order menu                    1
# Price range                             4
# Aggregate rating                       33
# Rating color                            6
# Rating text                             6
# Votes                                1012
# Country                                15

# %% [markdown]
# We can observe the columns Restaurant ID have 9551 unique values which means they have only one value count. So it not required for the prediction so we can drop it.

# %%
# Dropping Restaurant ID columns
df.drop("Restaurant ID",axis=1,inplace=True)

# %% [markdown]
# # Separating numerical and categorcal columns

# %%
# Checking for categorical columns
categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        categorical_col.append(i)
print("Categorical columns are:\n",categorical_col)
# Out:
# Categorical columns are:
#  ['Restaurant Name', 'City', 'Locality', 'Locality Verbose', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu', 'Rating color', 'Rating text', 'Country']

# %%
# checking for numerical columns
numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        numerical_col.append(i)
print("Numerical columns are:\n",numerical_col)
# Out:
# Numerical columns are:
#  ['Country Code', 'Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %%
# groupby 4 columns which are related to each other
df2 = df.groupby(['Aggregate rating','Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
df2
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [raw]
# Rating 0 - White - Not rated
#
# Rating 1.8 to 2.4 - Red - Poor
#
# *Rating 2.5 to 3.4 - Orange - Average
#
# Rating 3.5 to 3.9 - Yellow - Good
#
# Rating 4.0 to 4.4 - Green - Very Good
#
# Rating 4.5 to 4.9 - Dark Green - Excellent

# %%
# Checking the list of counts of target
df['Aggregate rating'].unique()
# Out:
# array([4.8, 4.5, 4.4, 4.9, 4. , 4.2, 4.3, 3.6, 4.7, 3. , 3.8, 3.7, 3.2,
#        3.1, 0. , 4.1, 3.3, 4.6, 3.9, 3.4, 3.5, 2.2, 2.4, 2.9, 2.6, 2.8,
#        2.1, 2.7, 2.5, 1.8, 2. , 2.3, 1.9])

# %%
df['Aggregate rating'].value_counts()
# Out:
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: Aggregate rating, dtype: int64

# %%
# Checking wheather the target vaiable contains any space
df.loc[df['Average Cost for two']==" "]
# Out:
# Empty DataFrame
# Columns: [Restaurant Name, Country Code, City, Locality, Locality Verbose, Longitude, Latitude, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes, Country]
# Index: []

# %%
No_rating = df[df['Rating color']=='White'].groupby('Country').size().reset_index().rename(columns={0:'Rating Count'})
No_rating
# Out:
#           Country  Rating Count
# 0          Brazil             5
# 1           India          2139
# 2  United Kingdom             1
# 3   United States             3

# %% [markdown]
# India seems to have maximum unrated restaurants. In India the culture of ordering online food is still gaining momentum hence most of the restaurants are still unrated on Zomato as people might be preferring to visiting the restaurant for a meal.

# %%
Max_rating = df[df['Rating color']=='Dark Green'].groupby('Country').size().reset_index().rename(columns={0:'Rating Count'})
Max_rating
# Out:
#            Country  Rating Count
# 0        Australia             1
# 1           Brazil            16
# 2            India           116
# 3        Indonesia             7
# 4      New Zealand            12
# 5      Phillipines            12
# 6            Qatar             4
# 7     South Africa            12
# 8        Sri Lanka             2
# 9           Turkey            10
# 10             UAE            18
# 11  United Kingdom            23
# 12   United States            68

# %% [markdown]
# Max rating restuarants are also found in India .. This may be because India has the maximum restuarants listed on Zomato from all over the world

# %%
country_currency = df[['Country','Currency']].groupby(['Country','Currency']).size().reset_index(name='count').drop('count', axis=1, inplace=False)
country_currency.sort_values('Currency').reset_index(drop=True)
# Out:
#            Country                Currency
# 0      Phillipines        Botswana Pula(P)
# 1           Brazil      Brazilian Real(R$)
# 2        Australia               Dollar($)
# 3           Canada               Dollar($)
# 4        Singapore               Dollar($)
# 5    United States               Dollar($)
# 6              UAE      Emirati Diram(AED)
# 7            India      Indian Rupees(Rs.)
# 8        Indonesia  Indonesian Rupiah(IDR)
# 9      New Zealand           NewZealand($)
# 10  United Kingdom              Pounds(��)
# 11           Qatar         Qatari Rial(QR)
# 12    South Africa                 Rand(R)
# 13       Sri Lanka   Sri Lankan Rupee(LKR)
# 14          Turkey        Turkish Lira(TL)

# %% [markdown]
# # EDA and data visualization

# %%
plt.figure(figsize=(15,10))
sns.countplot(df['Country'])
plt.title('Country', fontsize=10)
plt.grid()
df['Country'].value_counts()/9551*100
# Out:
# India             90.587373
# United States      4.544027
# United Kingdom     0.837609
# Brazil             0.628206
# UAE                0.628206
# South Africa       0.628206
# New Zealand        0.418804
# Turkey             0.355984
# Australia          0.251283
# Phillipines        0.230342
# Indonesia          0.219872
# Singapore          0.209402
# Qatar              0.209402
# Sri Lanka          0.209402
# Canada             0.041880
# Name: Country, dtype: float64

# %% [markdown]
# The highest restaurant of zomato is in India is shown by the graph.

# %%
(df['City'].value_counts()).plot(kind='pie',autopct='%1.1f%%', figsize=(30,15) )
plt.legend(title ="City",loc ="best",bbox_to_anchor =(1, 0.5, 0.5, 1))
plt.title("Percentage of different City used by Zomato Restaurants")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(40,30))
sns.countplot(y=df['City'])
plt.title('City', fontsize=10)
plt.grid()
df['City'].value_counts()/9551*100
# Out:
# New Delhi       57.302900
# Gurgaon         11.705581
# Noida           11.307716
# Faridabad        2.627997
# Ghaziabad        0.261753
#                   ...
# Huskisson        0.010470
# Panchkula        0.010470
# Forrest          0.010470
# Flaxton          0.010470
# Chatham-Kent     0.010470
# Name: City, Length: 141, dtype: float64

# %% [markdown]
# #The most of restaturants of zomato is in New delhi.

# %%
plt.figure(figsize=(40,30))
sns.countplot(y=df['Average Cost for two'])
plt.title('Average Cost for two', fontsize=10)
plt.grid()
df['Average Cost for two'].value_counts()/9551*100
# Out:
# 500       9.423097
# 300       9.391687
# 400       8.972882
# 200       7.192964
# 600       6.826510
#             ...
# 8000      0.010470
# 2350      0.010470
# 150000    0.010470
# 70000     0.010470
# 545       0.010470
# Name: Average Cost for two, Length: 140, dtype: float64

# %% [markdown]
# Average cost for two is lies between 300 to 500 rs.

# %%
plt.figure(figsize=(10,7))
sns.countplot(y=df['Price range'])
plt.title('Price range', fontsize=10)
plt.grid()
df['Price range'].value_counts()/9551*100
# Out:
# 1    46.529159
# 2    32.593446
# 3    14.741912
# 4     6.135483
# Name: Price range, dtype: float64

# %%
sns.pairplot(data=df, hue='Price range')

# %%
df['Cuisines'].value_counts()/9551*100
# Out:
# North Indian                                             9.800021
# North Indian, Chinese                                    5.350225
# Fast Food                                                3.706418
# Chinese                                                  3.706418
# North Indian, Mughlai                                    3.497016
#                                                            ...
# Bengali, Fast Food                                       0.010470
# North Indian, Rajasthani, Asian                          0.010470
# Chinese, Thai, Malaysian, Indonesian                     0.010470
# Bakery, Desserts, North Indian, Bengali, South Indian    0.010470
# Italian, World Cuisine                                   0.010470
# Name: Cuisines, Length: 1826, dtype: float64

# %%
#Lets list all the country now and do analysis
indiaRes=df[df['Country']=='India']
singaporeRes=df[df['Country']=='Singapore']
AusRes=df[df['Country']=='Australia']
BrazRes=df[df['Country']=='Brazil']
CanadaRes=df[df['Country']=='Canada']
UAERes=df[df['Country']=='UAE']
UKRes=df[df['Country']=='United Kingdom']
USRes=df[df['Country']=='United States']
SouthAfricaRes=df[df['Country']=='South Africa']
NewZelandRes=df[df['Country']=='New Zealand']
TurkeyRes=df[df['Country']=='Turkey']
IndonesiaRes=df[df['Country']=='Indonesia']
QatarRes=df[df['Country']=='Qatar']
SrilankaRes=df[df['Country']=='Sri Lanka']

# %%
indiaRes.head()
# Out:
#                            Restaurant Name  Country Code  City     Locality  \
# 624                             Jahanpanah             1  Agra   Agra Cantt
# 625                    Rangrezz Restaurant             1  Agra   Agra Cantt
# 626                Time2Eat - Mama Chicken             1  Agra   Agra Cantt
# 627  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra  Civil Lines
# 628                         Pinch Of Spice             1  Agra  Civil Lines
#
#       Locality Verbose  Longitude   Latitude                        Cuisines  \
# 624   Agra Cantt, Agra  78.011544  27.161661           North Indian, Mughlai
# 625   Agra Cantt, Agra   0.000000   0.000000           North Indian, Mughlai
# 626   Agra Cantt, Agra  78.011608  27.160832                    North Indian
# 627  Civil Lines, Agra  77.998092  27.195928                      Rajasthani
# 628  Civil Lines, Agra  78.007553  27.201725  North Indian, Chinese, Mughlai
#
# ...

# %%
indiaRes.City.value_counts()
# Out:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Guwahati          21
# Lucknow           21
# Bhubaneshwar      21
# Amritsar          21
# Pune              20
# Puducherry        20
# Patna             20
# Ludhiana          20
# Ranchi            20
# Surat             20
# Vadodara          20
# Nashik            20
# Nagpur            20
# Mysore            20
# Mumbai            20
# Varanasi          20
# Mangalore         20
# Agra              20
# Kochi             20
# Kolkata           20
# Dehradun          20
# Allahabad         20
# Aurangabad        20
# Bangalore         20
# Bhopal            20
# Chennai           20
# Coimbatore        20
# Goa               20
# Indore            20
# Jaipur            20
# Kanpur            20
# Vizag             20
# Chandigarh        18
# Hyderabad         18
# Secunderabad       2
# Panchkula          1
# Mohali             1
# ...

# %%
#plt.figure(figsize=(10,10))
sns.countplot(indiaRes['City'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# New Delhi has the highest Count of Restaurant in India and the least is Mohali

# %%
df['Price range'].value_counts()
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['Price range'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# We can see that the Price range 1 is max in number

# %%
def generate_pie(i):
    plt.figure(figsize=(10,5),facecolor='Pink')
    plt.pie(i.value_counts(), labels=i.value_counts().index, autopct='%1.2f%%',shadow=True,)
    plt.legend(prop={'size':14})
    plt.axis('equal')
    plt.tight_layout()
    return plt.show()

# %%
cols1 = ['Has Table booking', 'Has Online delivery', 'Is delivering now','Price range', 'Rating color','Rating text']

# %%
plotnumber=1
for j in df[cols1]:
    print(f"Pie plot for the column:", j)
    generate_pie(df[j])
# Out:
# Pie plot for the column: Has Table booking
# Pie plot for the column: Has Online delivery
# Pie plot for the column: Is delivering now
# Pie plot for the column: Price range
# Pie plot for the column: Rating color
# Pie plot for the column: Rating text

# %% [raw]
# Observation :-
# Online Delivery is very less in India.
# Very less company are delivery now.
# Maximum price range is 1.
# Rating color Orange in maximum.
# Rating Text is maximum Average.

# %% [markdown]
# Top cuisines in each region

# %%
IndianCuisines=df[df['Country']=='India']['Cuisines'].value_counts().head()
IndianCuisines
# Out:
# North Indian             936
# North Indian, Chinese    511
# Fast Food                348
# Chinese                  340
# North Indian, Mughlai    334
# Name: Cuisines, dtype: int64

# %%
plt.figure(figsize=(10,10))
indiaRes['Cuisines'].value_counts().head(10).plot(kind='pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Cuisines'>

# %% [markdown]
# North Indian dishes are most in counts and the least is street food

# %%
# Checking how the data has been distriubted in each column

plt.figure(figsize=(25,35),facecolor='white')
plotnumber=1
for column in numerical_col:
    if plotnumber<=23:
        ax=plt.subplot(6,4,plotnumber)
        sns.distplot(df[column],color="orange",hist=False,kde_kws={"shade": True})
        plt.xlabel(column,fontsize=18)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Data are skewed in dataset

# %%
rating_price= df.groupby('Price range').mean()['Aggregate rating'].sort_values(ascending=True)
print(rating_price)
(rating_price).plot(kind='line', xlabel='Price range', ylabel='Average of ratings', title='Average rating v/s Price range')
# Out:
# Price range
# 1    1.999887
# 2    2.941054
# 3    3.683381
# 4    3.817918
# Name: Aggregate rating, dtype: float64
# <AxesSubplot:title={'center':'Average rating v/s Price range'}, xlabel='Price range', ylabel='Average of ratings'>

# %%
plt.figure(figsize=(10,10))
sns.boxplot(indiaRes["Rating text"],indiaRes["Average Cost for two"])
# Out:
# <AxesSubplot:xlabel='Rating text', ylabel='Average Cost for two'>

# %% [markdown]
# The plot shows rating does influence the cost of service at a restaurant

# %%
print(df['Rating text'].unique())
print(df['Rating text'].nunique())
print(df['Rating text'].value_counts())
# Out:
# ['Excellent' 'Very Good' 'Good' 'Average' 'Not rated' 'Poor']
# 6
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: Rating text, dtype: int64

# %%
(df['Rating text'].value_counts()[:6]).plot(kind='bar', color=['orange','green','green','blue','green','red'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# maximum rating text is Average and the least is poor

# %%
#top ten rating restaurants
r1= (df.loc[df['Aggregate rating'] > 4.5, 'Restaurant Name'])
print(r1)
print(len(r1))
print(r1.value_counts())
((r1.value_counts()).head(10)).plot(kind='barh', color='black', figsize=(10,10))
plt.ylabel("Restaurants")
plt.title("Top 10 High Rated restaurant ")
# Out:
# 0                               Le Petit Souffle
# 3                                           Ooma
# 4                                    Sambo Kojin
# 8       Spiral - Sofitel Philippine Plaza Manila
# 9                                       Locavore
#                           ...
# 9536                             Pizza ��l Forno
# 9537                         J'adore Chocolatier
# 9538                                   Starbucks
# 9540                            Draft Gastro Pub
# 9544                       Karak�_y G�_ll�_o��lu
# Name: Restaurant Name, Length: 206, dtype: object
# 206
# Barbeque Nation                               7
# AB's - Absolute Barbecues                     4
# Talaga Sampireun                              3
# Chili's                                       3
# Mocha                                         2
#                                              ..
# Mr. Dunderbak's Biergarten and Marketplatz    1
# Datz                                          1
# ...

# %% [markdown]
# Barbeque Nation is the Max rated restaraunts in Top 10

# %%
df.groupby('Restaurant Name').mean()['Votes'].sort_values(ascending=False)
# Out:
# Restaurant Name
# Toit                               10934.0
# Hauz Khas Social                    7931.0
# Peter Cat                           7574.0
# Big Brewsky                         5705.0
# The Black Pearl                     5385.0
#                                     ...
# New Bhappe Di Hatti                    0.0
# New Aggarwal Sweets & Fast Food        0.0
# Nehra's Food Point                     0.0
# Negi Restaurant                        0.0
# Laxmi Food Corner                      0.0
# Name: Votes, Length: 7446, dtype: float64

# %%
df.plot(kind='box',subplots=True,layout=(10,5),figsize=(20,20),color='pink')
# Out:
# Country Code               AxesSubplot(0.125,0.816017;0.133621x0.0639831)
# Longitude               AxesSubplot(0.285345,0.816017;0.133621x0.0639831)
# Latitude                 AxesSubplot(0.44569,0.816017;0.133621x0.0639831)
# Average Cost for two    AxesSubplot(0.606034,0.816017;0.133621x0.0639831)
# Price range             AxesSubplot(0.766379,0.816017;0.133621x0.0639831)
# Aggregate rating           AxesSubplot(0.125,0.739237;0.133621x0.0639831)
# Votes                   AxesSubplot(0.285345,0.739237;0.133621x0.0639831)
# dtype: object

# %% [markdown]
# All the Numerical columns have Outlier present

# %%
df.nunique()
# Out:
# Restaurant Name         7446
# Country Code              15
# City                     141
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1826
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# Country                   15
# dtype: int64

# %%
# only no values are there in below column so droping it
df.drop("Switch to order menu",axis=1,inplace=True)

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=le.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#       Country Code  City  Locality  Locality Verbose   Longitude   Latitude  \
# 0              162    73       171               172  121.027535  14.565443
# 1              162    73       593               601  121.014101  14.553708
# 2              162    75       308               314  121.056831  14.581404
# 3              162    75       862               875  121.056475  14.585318
# 4              162    75       862               875  121.057508  14.584450
# ...            ...   ...       ...               ...         ...        ...
# 9546           208   140       517               523   28.977392  41.022793
# 9547           208   140       552               558   29.041297  41.009847
# 9548           208   140       554               561   29.034640  41.055817
# 9549           208   140       554               561   29.036019  41.057979
# 9550           208   140       670               681   29.026016  40.984776
#
# ...

# %%
df.corr()
# Out:
#                       Country Code      City  Locality  Locality Verbose  \
# Country Code              1.000000 -0.181728 -0.120076         -0.117543
# City                     -0.181728  1.000000  0.096443          0.093141
# Locality                 -0.120076  0.096443  1.000000          0.999465
# Locality Verbose         -0.117543  0.093141  0.999465          1.000000
# Longitude                -0.698299  0.117391  0.086446          0.084340
# Latitude                  0.019792 -0.004301 -0.020428         -0.020909
# Cuisines                 -0.132983  0.026632  0.007019          0.005986
# Average Cost for two      0.043225 -0.028838 -0.012136         -0.011852
# Currency                 -0.033466 -0.071996  0.023718          0.022960
# Has Table booking        -0.061682 -0.003762 -0.065594         -0.065132
# Has Online delivery      -0.154605  0.012723 -0.030993         -0.031766
# Is delivering now        -0.018291 -0.014039 -0.007299         -0.007353
# ...

# %%
# Visualizing the correlation matrix by plotting heat map.
plt.figure(figsize=(30,25))
sns.heatmap(df.corr(),linewidths=.1,vmin=-1, vmax=1, fmt='.2g', annot = True, linecolor="black",annot_kws={'size':10},cmap="ocean")
plt.yticks(rotation=0);

# %% [markdown]
# This heatmap shows the correlation matrix by visualizing the data. we can observe the relation between feature to feature and feature to label. This heat mapcontains both positive and negative correlation.

# %%
df.corr()['Average Cost for two'].sort_values()
# Out:
# Latitude               -0.111088
# Rating color           -0.049970
# City                   -0.028838
# Has Online delivery    -0.018974
# Locality               -0.012136
# Locality Verbose       -0.011852
# Country                -0.004034
# Is delivering now      -0.001862
# Cuisines                0.005819
# Has Table booking       0.007758
# Rating text             0.031439
# Country Code            0.043225
# Currency                0.045615
# Longitude               0.045891
# Aggregate rating        0.051792
# Votes                   0.067783
# Price range             0.075083
# Average Cost for two    1.000000
# Name: Average Cost for two, dtype: float64

# %%
#checking the columns which are positively and negatively correlated

plt.figure(figsize=(30,15))
df.corr()['Average Cost for two'].sort_values(ascending=False).drop(['Average Cost for two']).plot(kind='bar',color='blue')
plt.xlabel('Features',fontsize=40)
plt.ylabel('columns with target names',fontsize=20)
plt.title('CORRELATION',fontsize=40)
plt.show()

# %% [markdown]
# he least correlated columns are-> Is delivering now and Country and the max postive and Negative correlated columns as Price Range and Latitude.

# %%
df.drop("Is delivering now",axis=1,inplace=True)

# %%
df.drop("Country",axis=1,inplace=True)

# %%
df.describe().T
# Out:
#                        count         mean           std         min  \
# Country Code          9551.0    18.365616     56.750546    1.000000
# City                  9551.0    78.301434     23.198915    0.000000
# Locality              9551.0   658.128678    315.866877    0.000000
# Locality Verbose      9551.0   677.305204    331.727817    0.000000
# Longitude             9551.0    64.126574     41.467058 -157.948486
# Latitude              9551.0    25.854381     11.007935  -41.330428
# Cuisines              9551.0   989.883363    514.573865    0.000000
# Average Cost for two  9551.0  1199.210763  16121.183073    0.000000
# Currency              9551.0     3.977699      0.914242    0.000000
# Has Table booking     9551.0     0.121244      0.326428    0.000000
# Has Online delivery   9551.0     0.256622      0.436792    0.000000
# Price range           9551.0     1.804837      0.905609    1.000000
# Aggregate rating      9551.0     2.666370      1.516378    0.000000
# ...

# %%
plt.figure(figsize=(35,17))
sns.heatmap(df.describe(),annot=True,linewidths=0.5,linecolor="pink",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (9551, 16)

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# Country Code             3.043965
# City                    -1.193777
# Locality                -0.253550
# Locality Verbose        -0.183059
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.306743
# Average Cost for two    35.477915
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# dtype: float64

# %%
#Lets plot all using Histogram and see the skewness again
 
plt.rcParams['figure.figsize']=(30,20)
df.hist(bins=25,color='orange',density=True,label='Value',histtype='bar')
plt.tight_layout()
plt.show()

# %% [markdown]
# Country Code,Longitude,Latitude ,Average Cost for two,Price range,Aggregate rating,Votes have Skewness and it is needed to be removed ,Rest all columns which are showing skewness are catagorical columns and in this we are not required to remove skewness

# %% [markdown]
# # Outliers removal by ZSCORE METHOD

# %%
df.columns
# Out:
# Index(['Country Code', 'City', 'Locality', 'Locality Verbose', 'Longitude',
#        'Latitude', 'Cuisines', 'Average Cost for two', 'Currency',
#        'Has Table booking', 'Has Online delivery', 'Price range',
#        'Aggregate rating', 'Rating color', 'Rating text', 'Votes'],
#       dtype='object')

# %%
# Features containing outliers
features = df[['Country Code','Longitude','Latitude','Average Cost for two','Price range','Aggregate rating','Votes']]

# Using zscore to remove outliers
from scipy.stats import zscore

z=np.abs(zscore(features))

z
# Out:
#       Country Code  Longitude  Latitude  Average Cost for two  Price range  \
# 0         2.531111   1.372269  1.025581              0.006154     1.319803
# 1         2.531111   1.371945  1.026647              0.000049     1.319803
# 2         2.531111   1.372975  1.024131              0.173743     2.424090
# 3         2.531111   1.372966  1.023775              0.018659     2.424090
# 4         2.531111   1.372991  1.023854              0.018659     2.424090
# ...            ...        ...       ...                   ...          ...
# 9546      3.341718   0.847685  1.378025              0.069428     1.319803
# 9547      3.341718   0.846144  1.376849              0.067878     1.319803
# 9548      3.341718   0.846305  1.381025              0.063845     2.424090
# 9549      3.341718   0.846272  1.381221              0.066947     2.424090
# 9550      3.341718   0.846513  1.374571              0.070979     0.215516
#
#       Aggregate rating     Votes
# 0             1.407131  0.365202
# ...

# %%
# Creating new dataframe
dfn = df[(z<3).all(axis=1)] 
dfn
# Out:
#       Country Code  City  Locality  Locality Verbose   Longitude   Latitude  \
# 0              162    73       171               172  121.027535  14.565443
# 1              162    73       593               601  121.014101  14.553708
# 2              162    75       308               314  121.056831  14.581404
# 3              162    75       862               875  121.056475  14.585318
# 4              162    75       862               875  121.057508  14.584450
# ...            ...   ...       ...               ...         ...        ...
# 9432           166    38      1063              1116   51.526653  25.323261
# 9433           166    38      1086              1139   51.530127  25.350325
# 9434           166    38      1092              1145   51.512909  25.276180
# 9435           166    38      1115              1170   51.544576  25.273020
# 9436           166    38      1115              1170   51.546714  25.283011
#
# ...

# %%
dfn.shape
# Out:
# (8565, 16)

# %%
df.shape
# Out:
# (9551, 16)

# %%
# Percentage of data loss

DataLoss=((9551-8565)/9551)*100
DataLoss
# Out:
# 10.323526332321222

# %% [markdown]
# # Remove skewness

# %%
L1=['Country Code','Longitude','Latitude' ,'Average Cost for two','Price range','Aggregate rating','Votes']

# %%
# Lets remove the skewness from given columns by Power Transform Method

from sklearn.preprocessing import PowerTransformer
ps = PowerTransformer(method='yeo-johnson')

# %%
#Removing skewness using yeo-johnson
dfn[['Country Code','Longitude','Latitude' ,'Average Cost for two','Price range','Aggregate rating','Votes']] = ps.fit_transform(dfn[['Country Code','Longitude','Latitude' ,'Average Cost for two','Price range','Aggregate rating','Votes']])

# %%
#After removing let's check how the data has been distributed in each column of skew_features.

plt.figure(figsize=(20,25), facecolor='pink')
plotnumber = 1

for column in dfn[L1]:
    if plotnumber<=9:
        ax = plt.subplot(2,7,plotnumber)
        sns.distplot(dfn[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()

# %% [markdown]
# # Splitting the data in teain and test mode

# %%
dfn.head(3)
# Out:
#    Country Code  City  Locality  Locality Verbose  Longitude  Latitude  \
# 0     11.616899    73       171               172   7.096817 -2.870154
# 1     11.616899    73       593               601   7.094048 -2.870996
# 2     11.616899    75       308               314   7.102859 -2.869007
#
#    Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0       920              1.170136         0                  1
# 1      1111              1.291498         0                  1
# 2      1672              3.044151         0                  1
#
#    Has Online delivery  Price range  Aggregate rating  Rating color  \
# 0                    0     1.385129          1.972392             0
# 1                    0     1.385129          1.649065             0
# 2                    0     1.744844          1.543945             1
#
#    Rating text     Votes
# 0            1  1.410787
# 1            1  1.753948
# 2            5  1.329422

# %%
x=dfn.loc [:,dfn.columns != 'Average Cost for two']

# %%
y=dfn.loc[:,'Average Cost for two']

# %%
x.shape,y.shape
# Out:
# ((8565, 15), (8565,))

# %% [markdown]
# # Scaling the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

x= pd.DataFrame(sc.fit_transform(x), columns=x.columns)
x
# Out:
#       Country Code      City  Locality  Locality Verbose  Longitude  Latitude  \
# 0        11.616901 -0.350524 -1.639342         -1.617142   7.096817 -2.870154
# 1        11.616901 -0.350524 -0.261938         -0.285302   7.094048 -2.870996
# 2        11.616901 -0.246545 -1.192175         -1.176300   7.102859 -2.869007
# 3        11.616901 -0.246545  0.616075          0.565336   7.102785 -2.868725
# 4        11.616901 -0.246545  0.616075          0.565336   7.102998 -2.868788
# ...            ...       ...       ...               ...        ...       ...
# 8560     11.616901 -2.170157  1.272136          1.313526  -2.075973 -0.937919
# 8561     11.616901 -2.170157  1.347208          1.384930  -2.075747 -0.929022
# 8562     11.616901 -2.170157  1.366792          1.403557  -2.076865 -0.953334
# 8563     11.616901 -2.170157  1.441864          1.481170  -2.074809 -0.954365
# 8564     11.616901 -2.170157  1.441864          1.481170  -2.074670 -0.951102
#
# ...

# %% [markdown]
# # VIF (MULTICOLLINEARITY)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def vif_cal():
    vif=pd.DataFrame()
    vif["VIF FACTOR"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    vif["FEATURES"]=x.columns
    print (vif)

# %%
vif_cal()
# Out:
#     VIF FACTOR             FEATURES
# 0     1.461026         Country Code
# 1     1.078664                 City
# 2   886.414838             Locality
# 3   886.135223     Locality Verbose
# 4     3.080093            Longitude
# 5     2.787892             Latitude
# 6     1.025043             Cuisines
# 7     1.503753             Currency
# 8     1.395456    Has Table booking
# 9     1.230983  Has Online delivery
# 10    1.758696          Price range
# 11    4.708945     Aggregate rating
# 12    1.239534         Rating color
# 13    1.305338          Rating text
# 14    5.042861                Votes

# %%
x.drop("Locality",axis=1,inplace=True)

# %%
x.drop("Locality Verbose",axis=1,inplace=True)

# %% [markdown]
# # Model building

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print (f"At random state {i},the training accuracy is :- {r2_score(y_train,pred_train)}")
    print (f"At random state {i},the testing accuracy is :- {r2_score(y_test,pred_test)}")
    print ("\n\n")
# Out:
# At random state 0,the training accuracy is :- 0.7359298384060179
# At random state 0,the testing accuracy is :- 0.7441329870497422
#
#
#
# At random state 1,the training accuracy is :- 0.7351179368072184
# At random state 1,the testing accuracy is :- 0.7485398788171425
#
#
#
# At random state 2,the training accuracy is :- 0.7391116587046026
# At random state 2,the testing accuracy is :- 0.7324271654154513
#
#
#
# At random state 3,the training accuracy is :- 0.74042333212419
# At random state 3,the testing accuracy is :- 0.7268683678330768
#
#
#
# At random state 4,the training accuracy is :- 0.7312439250558931
# At random state 4,the testing accuracy is :- 0.7633765528722484
#
#
#
# At random state 5,the training accuracy is :- 0.733568810083634
# At random state 5,the testing accuracy is :- 0.7530473076890327
#
#
#
# At random state 6,the training accuracy is :- 0.7365828762761333
# At random state 6,the testing accuracy is :- 0.7420002592163042
#
#
#
# ...

# %% [markdown]
# At random state 50,the training accuracy is :- 0.7309695473387743
# At random state 50,the testing accuracy is :- 0.7675535099892103 model is performing good.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=50)

# %%
# train the model
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# predict the  data with x_test

pred_test=lr.predict(x_test)

# %%
print (r2_score(y_test,pred_test))
# Out:
# 0.7675535099892103

# %% [markdown]
# # Cross validation

# %%
pred_lr=lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=r2_score(y_test,pred_lr)

# %%
for i in range(4,10):
    lsscore=cross_val_score(lr,x,y,cv=i)
    lsc=lsscore.mean()
    print ("At cv:-",i)
    print ("Cross validation score is :-",lsc*100)
    print ("Accuracy_score is :-",lss*100)
    print ("\n")
# Out:
# At cv:- 4
# Cross validation score is :- -4.072565749126306
# Accuracy_score is :- 76.75535099892103
#
#
# At cv:- 5
# Cross validation score is :- 44.2018098597194
# Accuracy_score is :- 76.75535099892103
#
#
# At cv:- 6
# Cross validation score is :- 44.871997027089925
# Accuracy_score is :- 76.75535099892103
#
#
# At cv:- 7
# Cross validation score is :- 46.11044986189944
# Accuracy_score is :- 76.75535099892103
#
#
# At cv:- 8
# Cross validation score is :- 44.3309350338818
# Accuracy_score is :- 76.75535099892103
#
#
# At cv:- 9
# Cross validation score is :- 45.53490496455467
# Accuracy_score is :- 76.75535099892103

# %% [markdown]
# At cv:- 6
# Cross validation score is :- 44.871997027089925
# Accuracy_score is :- 76.75535099892103 model is performing well.

# %%
lsscore_selected= cross_val_score(lr,x,y,cv=6).mean()
print ("The cv score is :- ",lsscore_selected,"\nThe accuracy_score is:",lss)
# Out:
# The cv score is :-  0.44871997027089927
# The accuracy_score is: 0.7675535099892103

# %%
from sklearn import metrics

# %%
MAE= metrics.mean_absolute_error(y_test,pred_test)
MSE= metrics.mean_squared_error(y_test,pred_test)

# %%
print("mean absolute error:",MAE)
print("mean squared error:",MSE)
# Out:
# mean absolute error: 0.35721988303942936
# mean squared error: 0.21420201810335196

# %%
from math import sqrt
rmse = sqrt(MSE)
print("Root Mean Squared Error:",rmse)
# Out:
# Root Mean Squared Error: 0.4628196388479555

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.scatter (x=y_test,y=pred_test,color='black')

plt.plot(y_test,y_test,color='b')

plt.xlabel('Actual charges' ,fontsize=14)

plt.ylabel('Predicted charges', fontsize=14)
plt.title('Linear Regression' , fontsize=20)
plt. show()

# %% [markdown]
# Most of the points falls on the best fit line which is good

# %%
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor 
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %% [markdown]
# # 2. Decisiontree regressor

# %%
# Checking R2 score for Decision Tree Regressor
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)

# prediction
predDTR=DTR.predict(x_test)
dt=r2_score(y_test,predDTR)
print('R2_Score:',dt)

print('cv :-' ,cross_val_score(DTR,x,y,cv=6).mean())
print('MAE:',metrics.mean_absolute_error(y_test, predDTR))
print('MSE:',metrics.mean_squared_error(y_test, predDTR))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predDTR)))

# Visualizing the predicteed values
plt.figure(figsize=(10,10))
sns.regplot(y_test,predDTR,color="purple")
plt.show()
# Out:
# R2_Score: 0.7165812107034206
# cv :- 0.5852583831266488
# MAE: 0.3458715803644309
# MSE: 0.261173557118105
# RMSE: 0.5110514231641519

# %% [markdown]
# # 3. Ensemble Technique
# Random forest regressor

# %%
RF=RandomForestRegressor()
RF.fit(x_train,y_train)

predRF=RF.predict(x_test)
print('R2_Score:',r2_score(y_test,predRF))
print('MAE:',metrics.mean_absolute_error(y_test, predRF))
print('MSE:',metrics.mean_squared_error(y_test, predRF))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predRF)))
print('cv :-' ,cross_val_score(RF,x,y,cv=6).mean())

# Visualizing the predicteed values
plt.figure(figsize=(10,10))
sns.regplot(y_test,predRF,color="purple")
plt.show()
# Out:
# R2_Score: 0.8366753130796081
# MAE: 0.2746665048712017
# MSE: 0.1505055100759843
# RMSE: 0.387950396411686
# cv :- 0.7022469242321079

# %% [markdown]
# # 4. Gradient boosting regressor

# %%
gb=GradientBoostingRegressor()
gb.fit(x_train,y_train)

# prediction
predgb=gb.predict(x_test)
print('R2_Score:',r2_score(y_test,predgb))
print('MAE:',metrics.mean_absolute_error(y_test, predgb))
print('MSE:',metrics.mean_squared_error(y_test, predgb))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predgb)))
print('cv :-' ,cross_val_score(gb,x,y,cv=6).mean())

# Visualizing the predicteed values
plt.figure(figsize=(10,10))
sns.regplot(y_test,predgb,color="purple")
plt.show()
# Out:
# R2_Score: 0.8458671048160677
# MAE: 0.28459528924146377
# MSE: 0.14203517206466829
# RMSE: 0.3768755392230548
# cv :- 0.6972345188270607

# %% [markdown]
# # 5. Extra tree regressor

# %%
# Checking R2 score for Extra Trees Regressor

XT=ExtraTreesRegressor()
XT.fit(x_train,y_train)

# prediction
predXT=XT.predict(x_test)
etr=r2_score(y_test,predXT)
print('R2_Score:',etr)

print('cv :-' ,cross_val_score(XT,x,y,cv=6).mean())


# Metric Evaluation
print('MAE:',metrics.mean_absolute_error(y_test, predXT))
print('MSE:',metrics.mean_squared_error(y_test, predXT))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predXT)))

# Visualizing the predicted values
plt.figure(figsize=(10,10))
sns.regplot(y_test,predXT,color="crimson")
plt.show()
# Out:
# R2_Score: 0.8260663092452346
# cv :- 0.7739496330258439
# MAE: 0.28274671095594445
# MSE: 0.1602818247507445
# RMSE: 0.40035212594757696

# %% [markdown]
# # Gradient boosting regressor is performing best.

# %% [markdown]
# # Hyper parameter tuning

# %%
gb.get_params()
# Out:
# {'alpha': 0.9,
#  'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.1,
#  'loss': 'squared_error',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_iter_no_change': None,
#  'random_state': None,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
#Gradient boosting regressor
parameters = {'criterion':['friedman_mse', 'squared_error'],
             'max_features':['auto', 'sqrt', 'log2'],
             'loss':['squared_error','absolute_error','huber','quantile'],
             'warm_start':[True,False]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
gv=GridSearchCV(GradientBoostingRegressor(),parameters,cv=6)

# %%
gv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=6, estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['friedman_mse', 'squared_error'],
#                          'loss': ['squared_error', 'absolute_error', 'huber',
#                                   'quantile'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'warm_start': [True, False]})

# %%
gv.best_params_
# Out:
# {'criterion': 'squared_error',
#  'loss': 'squared_error',
#  'max_features': 'auto',
#  'warm_start': True}

# %%
gb = GradientBoostingRegressor(criterion='squared_error', warm_start=True, max_features='auto',loss='squared_error')
gb.fit(x_train, y_train)
pred = gb.predict(x_test)
print('R2_Score:',r2_score(y_test,pred)*100)
# Out:
# R2_Score: 84.58081949575964

# %% [markdown]
# # Saving the model

# %%
#Saving the model using .pkl
import joblib
joblib.dump(gb,"Zomato.pkl")
# Out:
# ['Zomato.pkl']

# %%
#Loading the saved model
zm=joblib.load("Zomato.pkl")

# %%
zm
# Out:
# GradientBoostingRegressor(criterion='squared_error', max_features='auto',
#                           warm_start=True)

# %%
#Prediction
prediction = zm.predict(x_test)
prediction
# Out:
# array([ 0.40160907,  0.30601725,  0.35452652, ...,  1.51575582,
#        -0.80065216, -0.66582485])

# %%
pd.DataFrame([zm.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
# Out:
#                0         1         2         3         4         5     \
# Predicted  0.401609  0.306017  0.354527 -0.850825  0.352801  0.346087
# Original   0.644181  0.101782  0.343860 -1.070567  0.101782  0.550848
#
#                6         7         8         9     ...      1703      1704  \
# Predicted -0.793668 -0.531747 -0.795424 -0.783284  ... -0.594713  0.708455
# Original  -0.190489 -1.070567 -0.190489 -0.560837  ... -0.560837  0.814597
#
#                1705      1706      1707      1708      1709      1710  \
# Predicted -0.788873 -0.495712  0.356817 -0.733031 -1.139590  1.515756
# Original  -0.363292 -0.190489  0.343860 -1.070567 -0.560837  1.605942
#
#                1711      1712
# Predicted -0.800652 -0.665825
# Original  -0.363292 -1.070567
#
# [2 rows x 1713 columns]
